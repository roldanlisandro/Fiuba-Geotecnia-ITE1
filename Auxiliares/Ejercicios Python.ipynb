# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/roldanlisandro/Fiuba-Geotecnia-ITE1/blob/main/Auxiliares/Ejercicios%20Python.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Ejercicios Python
# Interacción Terreno-Estructura I
#
# Especialización en Ingeniería Geotécnica
#
# Dpto. de Estabilidad - Facultad de Ingeniería - UBA

# %% [markdown]
# # Ejercicio 1
# 1. Crear una función que evalúe la siguiente función
#
# $f(x)=\begin{array}{cc}
#   \ &
#     \begin{array}{cc}
#       x & x\leq 1 \\
#       x^2 & x > 1.
#     \end{array}
# \end{array}$
#
# 2. Crear una lista con los valores $[-1,0,1,2]$.
# 3. Crear un loop que evalúe la función en cada item de la lista e imprima el resultado.
# 4. Almacenar los resultados en una nueva lista

# %% [markdown]
# # Ejercicio 2
#
# Crear una variable de Python que tenga la información de la image. Luego acceder a las partes de la variable resaltadas.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Ejercicio 3
#
# Se cuenta con los puntos x e y que se muestran en la figura.
#
# 1.   Graficar los puntos con la función `scatter` de matplotlib
# 1.   Crear una función lineal que ajuste a los datos (a ojo).
# 2.   Graficar la función ajustada junto con los datos.
# 3.   Dar formato al gráfico (título, ejes, grilla, colores, trazos, leyendas)

# %%
y=np.array([ 3.52972704,  4.39015783,  4.13442583,  4.6679199 ,  5.59185897,
        6.55949166,  7.02649694,  7.251419  ,  6.07284005,  6.97626852,
        7.21958598,  7.30766542,  8.19718605,  8.36498036,  9.51971835,
        8.66619692,  8.51988626, 10.83109531, 10.89780985, 11.34635117,
       11.6781318 , 10.41652256, 12.04262642, 12.36053948, 12.65978689,
       12.84639878, 12.15090542, 13.5278727 , 14.23718629, 14.07479836])

x=np.array([ 0.        ,  0.34482759,  0.68965517,  1.03448276,  1.37931034,
        1.72413793,  2.06896552,  2.4137931 ,  2.75862069,  3.10344828,
        3.44827586,  3.79310345,  4.13793103,  4.48275862,  4.82758621,
        5.17241379,  5.51724138,  5.86206897,  6.20689655,  6.55172414,
        6.89655172,  7.24137931,  7.5862069 ,  7.93103448,  8.27586207,
        8.62068966,  8.96551724,  9.31034483,  9.65517241, 10.        ])

# %% [markdown]
# 5.    Usar la función curve_fit de scipy para hacer una regresión lineal sobre los puntos

# %% [markdown]
# # Ejercicio 4
#
# Resolver un sistema de ecuaciones
#
#
# $x+y=1$
#
# $2x+z=2$
#
# $y+3z=-2$
