# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/roldanlisandro/Fiuba-Geotecnia-ITE1/blob/main/Trabajos%20Practicos/TP4%20-%20Fundaciones%20superficiales.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Trabajo Práctico 4 - Fundaciones superficiales
# Interacción Terreno-Estructura I
#
# Especialización en Ingeniería Geotécnica
#
# Dpto. de Estabilidad - Facultad de Ingeniería - UBA

# %% [markdown]
# **Alumno**:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.integrate import quad

# %% [markdown]
# ## Introducción
#
# El objetivo de este trabajo práctico es familiarizarnos con los métodos clásicos de capacidad de carga de fundaciones superficiales y estimación de asentamientos.

# %% [markdown]
# # Ejercicio 1
#
# Para la fundación superficial corrida de 2.0m apoyada sobre una arcilla a 0.75m de profundidad se requiere determinar la carga aplicada que causará la falla por capacidad de carga de la zapata, $P_{ult}$ $[kN/m]$
#
# ![image.png](data:image/png;base64,...)
#
# El perfil geotécnico se describe en la siguiente tabla. La profundida del nivel freático es de 2.0m.
#
# ![image.png](data:image/png;base64,...)

# %%
## Codigo del alumno

# %% [markdown]
# Respuesta - $P_{ult} = [kN/m]$

# %% [markdown]
# # Ejercicio 2
#
# La siguiente figura muestra los resultados de un sondeo CPT efectuado en un determinado sitio. El perfil de suelo consiste en arenas normalmente consolidadas con algunos limos intercalados. El nivel freático se ubica a una profundidad de 2.0m. Se requiere ejecutar una zapata de 2.5m por 30m de largo para soportar una carga total, incluyendo el peso de la zapata y el suelo de relleno, igual a 197kPa y se cimentará a una profundidad de 2.0m.
#
# Utilice el método de Schmertmann para calcular el asentamiento de esta zapata poco después de su construcción y el asentamiento a 50 años.
#
# * Ayuda: ver capítulo 3.3.3 de Shallow Foundation. Baban 2016.
#
# ![image.png](data:image/png;base64,...)

# %%
## Código del alumno

# %% [markdown]
# Respuesta
#
#
#
# *   Asentamiento luego de la construcción: mm
# *   Asentamiento a 50 años: mm
